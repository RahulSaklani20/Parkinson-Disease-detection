# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("parkinsons.data.csv")
df.head(5)
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
df.shape
# Out:
# (195, 24)

# %%
df.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
df.isna().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
df['status'].value_counts()
# Out:
# 1    147
# 0     48
# Name: status, dtype: int64

# %%
sns.countplot(x='status', data=df,)
plt.show()

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(data=df.corr(), annot=True, cmap='coolwarm')
plt.title("Corelation between features")
plt.show()
# Out:
# C:\Users\rsakl\AppData\Local\Temp\ipykernel_10224\1526133166.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=df.corr(), annot=True, cmap='coolwarm')

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
x=df.drop(["name","status","NHR",'MDVP:Fhi(Hz)','DFA'],axis=1)
y=df['status']
scaler=StandardScaler()
x=scaler.fit_transform(x)
print(x.shape)
print(y.shape)
# Out:
# (195, 19)
# (195,)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=12)

# %% [markdown]
# KNN

# %%
#Checking the best value for k
d = {}
for i in range(2,int(df.shape[0]**0.5)):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(x_train, y_train)
    test_pred = knn.predict(x_test)
    ac = accuracy_score(test_pred, y_test)
    d[i] = ac
best_k = max(d, key=d.get)
max_accuracy = d[best_k]
print("Max Accuracy:",max_accuracy, "for k =", best_k)

# Plotting the values
plt.plot(list(d.keys()), list(d.values()))
plt.xlabel('k values')
plt.ylabel('Accuracy')
plt.title('Accuracy for different k values in KNN')
plt.show()
# Out:
# Max Accuracy: 0.9487179487179487 for k = 3

# %%
knn=KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train,y_train)
train_pred=knn.predict(x_train)
test_pred=knn.predict(x_test)
a1=(accuracy_score(train_pred,y_train)*100)
a2=(accuracy_score(y_test,test_pred)*100)
print("Training Accuracy:",a1)
print("Testing Accuracy:",a2)
# Out:
# Training Accuracy: 96.7948717948718
# Testing Accuracy: 94.87179487179486

# %%
sns.heatmap(data=confusion_matrix(test_pred,y_test),annot=True)
# Out:
# <Axes: >

# %%
print(classification_report(test_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.83      0.91        12
#            1       0.93      1.00      0.96        27
#
#     accuracy                           0.95        39
#    macro avg       0.97      0.92      0.94        39
# weighted avg       0.95      0.95      0.95        39

# %% [markdown]
# Support Vector Classifier Kernel=poly

# %%
from sklearn.svm import SVC
svc=SVC(kernel='poly')
svc.fit(x_train,y_train)
pred1=svc.predict(x_train)
pred2=svc.predict(x_test)
a3=accuracy_score(pred1,y_train)*100
a4=accuracy_score(pred2,y_test)*100
print("Training Accuracy:",a3)
print("Testing Accuracy:",a4)
# Out:
# Training Accuracy: 86.53846153846155
# Testing Accuracy: 84.61538461538461

# %% [markdown]
# Support Vector Classifier Kernel=linear

# %%
svc=SVC(kernel='linear')
svc.fit(x_train,y_train)
pred3=svc.predict(x_train)
pred4=svc.predict(x_test)
a5,a6=accuracy_score(pred3,y_train)*100,accuracy_score(pred4,y_test)*100
print("Training Accuracy:",a5)
print("Testing Accuracy:",a6)
# Out:
# Training Accuracy: 91.66666666666666
# Testing Accuracy: 82.05128205128204

# %% [markdown]
# Support Vector Classifier Kernel=rbf

# %%
svc=SVC(kernel='rbf')
svc.fit(x_train,y_train)
pred5=svc.predict(x_train)
pred6=svc.predict(x_test)
a7,a8=accuracy_score(pred5,y_train)*100,accuracy_score(pred6,y_test)*100
print("Training Accuracy:",a7)
print("Testing Accuracy:",a8)
# Out:
# Training Accuracy: 89.1025641025641
# Testing Accuracy: 84.61538461538461

# %% [markdown]
# Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
pred7=dt.predict(x_train)
pred8=dt.predict(x_test)
a9=accuracy_score(pred7,y_train)*100
a10=accuracy_score(pred8,y_test)*100
print("Training Accuracy:",a9)
print("Testing Accuracy:",a10)
# Out:
# Training Accuracy: 100.0
# Testing Accuracy: 84.61538461538461

# %% [markdown]
# Comparison Table

# %%
c={"Model":["KNN",'SVC(poly)','SVC(rbf)',"DecisionTreeClassifier",'SVC(linear)'],'Training Accuracy':[a1,a3,a7,a9,a5],'Testing Accuracy':[a2,a4,a8,a10,a6]}
c=pd.DataFrame(c)
c
# Out:
#                     Model  Training Accuracy  Testing Accuracy
# 0                     KNN          96.794872         94.871795
# 1               SVC(poly)          86.538462         84.615385
# 2                SVC(rbf)          89.102564         84.615385
# 3  DecisionTreeClassifier         100.000000         84.615385
# 4             SVC(linear)          91.666667         82.051282
